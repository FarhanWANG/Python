# %%
import requests
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36",
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
#     "Accept-Encoding": "gzip, deflate, sdch",
}

url = "https://www.glazziq.com/th/c/l/t-16"
response = requests.get(url,headers = header)

# %%
# from bs4 import BeautifulSoup
# soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
from lxml import html
import requests
  
# Request the page
page = requests.get('https://www.glazziq.com/th/c/l/t-16')
  
# Parsing the page
# (We need to use page.content rather than 
# page.text because html.fromstring implicitly
# expects bytes as input.)
tree = html.fromstring(page.content)  
  
# Get element using XPath
# //*[@id="product-listing"]/div/div[1]/div[2]/a/div/div[1]
product = tree.xpath('//*[@id="product-listing"]/div/div[3]/div[2]/a/div/div[1]/text()')
print(product)
# Out:
# ['Wilson']

# %%
tree.xpath('//.')
# Out:
# [<Element html at 0x242375ccc20>,
#  <Element head at 0x242332d54a0>,
#  <Element script at 0x2423335e310>,
#  'window.locale = "th"',
#  <Element meta at 0x2423335e040>,
#  <Element meta at 0x2423335e180>,
#  <Element meta at 0x2423335e090>,
#  <Element title at 0x2423335e680>,
#  'GLAZZIQ | แว่นตา แว่นสายตา กรอบ+เลนส์ เริ่ม 1,990 บาท',
#  '\n',
#  <Element meta at 0x2423335e7c0>,
#  '\n',
#  <Element meta at 0x2423335e810>,
#  '\n',
#  <Element link at 0x2423335e900>,
#  '\n',
#  <Element meta at 0x2423335e8b0>,
#  '\n',
#  <Element meta at 0x2423335e950>,
#  '\n',
#  <Element meta at 0x2423335e860>,
#  '\n',
#  <Element meta at 0x2423335e6d0>,
#  '\n',
#  <Element meta at 0x2423335e540>,
#  '\n',
#  <Element meta at 0x2423335e400>,
#  <Element link at 0x2423335e270>,
#  <!-- Google Tag Manager -->,
#  '\n',
#  <Element script at 0x242332f0a90>,
#  '\n//<![CDATA[\n\n        window.dataLayer = window.dataLayer || [];\n      \n//]]>\n',
#  '\n\n\n  ',
#  <Element script at 0x242332f0c20>,
#  '(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n  \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl+"&gtm_auth=QpYZeYFNasLASZNtQi0SAw&gtm_preview=env-2&gtm_cookies_win=x";f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',"GTM-MKKVWVG");',
#  '\n\n',
#  <Element script at 0x242332f0a40>,
#  "\n//<![CDATA[\n\n        window.dataLayer.push({\n          'event':'pjaxPageView',\n          'virtualUrl': 'https://www.glazziq.com/th/c/l/t-16'\n         });\n      \n//]]>\n",
#  '\n\n',
#  <!-- End Google Tag Manager -->,
#  '\n',
#  <Element link at 0x242332f08b0>,
#  <Element script at 0x242332f0040>,
#  <Element script at 0x242332f0ea0>,
#  <Element script at 0x242332f0ef0>,
#  <Element meta at 0x242332f0f90>,
#  '\n',
#  <Element meta at 0x242332f0f40>,
#  '\n  ',
#  <Element link at 0x242332f0c70>,
#  '\n  ',
#  <Element link at 0x242332f09a0>,
#  '\n  ',
#  <Element link at 0x242332f0950>,
#  '\n  ',
#  <Element link at 0x242332f0900>,
#  '\n  ',
#  <Element link at 0x242332f0090>,
#  '\n  ',
#  <Element link at 0x242332f0590>,
#  '\n  ',
#  <Element link at 0x242332f0770>,
#  '\n  ',
#  <Element link at 0x242332f0680>,
#  '\n  ',
#  <Element link at 0x242332f0220>,
#  '\n  ',
#  <Element link at 0x242332f0310>,
#  '\n  ',
#  <Element link at 0x242332f04f0>,
#  '\n  ',
#  <Element link at 0x242332f04a0>,
#  '\n  ',
#  <Element link at 0x242332f03b0>,
#  '\n  ',
#  <Element link at 0x242332f0bd0>,
#  '\n  ',
#  <Element link at 0x242332f05e0>,
#  '\n  ',
#  <Element link at 0x242332f0270>,
#  '\n  ',
#  <Element meta at 0x24237547c20>,
#  '\n  ',
#  <Element meta at 0x242332d6b80>,
#  '\n  ',
#  <Element meta at 0x242332d6c20>,
#  '\n',
#  <Element script at 0x242332d69a0>,
#  '(function(url, callback) {\n  var script = document.createElement( "script" );\n  script.type = "text/javascript";\n  script.async = "async";\n  script.onload = callback;\n  script.src = url;\n  document.getElementsByTagName( "head" )[0].appendChild( script );\n})(\n  \'//cdnt.netcoresmartech.com/smartechclient.js\',\n  function() {\n    smartech(\'create\', \'ADGMOT35CHFLVDHBJNIG50K96AGOQS8MKFSS4EALL5DOEL5JGUNG\');\n    smartech(\'register\', \'3b67808182b77eae361f6d2a387f2827\');\n    smartech(\'identify\', \'\');\n  }\n)',
#  <Element script at 0x242332d69f0>,
#  '\n//<![CDATA[\n{\n  "@context": "http://schema.org",\n  "@type": "BreadcrumbList",\n  "itemListElement": [\n\n  ]\n}\n//]]>\n',
#  <Element body at 0x242332e73b0>,
#  <!-- Google Tag Manager (noscript) -->,
#  '\n\n',
#  <Element noscript at 0x242332d6a40>,
#  '\n  ',
#  <Element iframe at 0x242332d6900>,
#  '\n',
#  '\n',
#  <!-- End Google Tag Manager (noscript) -->,
#  '\n',
#  <Element div at 0x242332d6a90>,
#  <Element div at 0x242332d63b0>,
#  <Element section at 0x242332d6360>,
#  <Element div at 0x242332e7180>,
#  <Element script at 0x242332e7310>,
#  '\n//<![CDATA[\nwindow.serverExports={};\n//]]>\n',
#  <Element div at 0x242332e72c0>,
#  <Element div at 0x242332e7450>,
#  <Element nav at 0x242332e75e0>,
#  <Element div at 0x242377296d0>,
#  <Element form at 0x242332e7db0>,
#  <InputElement 242332d5220 name='utf8' type='hidden'>,
#  <Element div at 0x242332d5ef0>,
#  <Element ul at 0x242332d5e50>,
#  <Element li at 0x242377cc400>,
#  <Element label at 0x242377cc090>,
#  <InputElement 242377cc3b0 name='filters[hto_only]' type='hidden'>,
#  <InputElement 24233367630 name='filters[hto_only]' type='checkbox'>,
#  '\xa0ลองที่บ้านได้',
#  <Element div at 0x242333679f0>,
#  <Element ul at 0x24233367d60>,
#  <Element li at 0x24233367db0>,
#  <Element a at 0x24233367040>,
#  'สี',
#  <Element span at 0x24233367cc0>,
#  <Element ul at 0x24233367d10>,
#  <InputElement 24233367590 name='filters[color_tone][]' type='hidden'>,
#  <Element li at 0x24233367bd0>,
#  <Element label at 0x24233367b80>,
#  <InputElement 24233367c20 name='filters[color_tone][]' type='checkbox'>,
#  ' โทนขาวดำ',
#  <Element li at 0x24233367130>,
#  <Element label at 0x24233367b30>,
#  <InputElement 24233367770 name='filters[color_tone][]' type='checkbox'>,
#  ' โทนหลากสี',
#  <Element li at 0x242333676d0>,
#  <Element label at 0x242333675e0>,
#  <InputElement 24233367810 name='filters[color_tone][]' type='checkbox'>,
#  ' เอิร์ธโทน',
#  <Element li at 0x24233367860>,
#  <Element label at 0x24233367950>,
#  <InputElement 24233367900 name='filters[color_tone][]' type='checkbox'>,
#  ' โทนสองสี',
#  <Element li at 0x242333678b0>,
#  <Element label at 0x24233367720>,
#  <InputElement 24233367e00 name='filters[color_tone][]' type='checkbox'>,
#  ' โทนสีเดียว',
#  <Element li at 0x24233367180>,
#  <Element a at 0x242333671d0>,
#  'วัสดุ',
#  <Element span at 0x24233367220>,
#  <Element ul at 0x24233367270>,
#  <InputElement 242333672c0 name='filters[derived_material_type][]' type='hidden'>,
#  <Element li at 0x24233367310>,
#  <Element label at 0x24233367360>,
#  <InputElement 242333673b0 name='filters[derived_material_type][]' type='checkbox'>,
#  ' โลหะ',
#  <Element li at 0x24233367400>,
#  <Element label at 0x24233367450>,
#  <InputElement 242333674a0 name='filters[derived_material_type][]' type='checkbox'>,
#  ' พลาสติก',
#  <Element li at 0x242333674f0>,
#  <Element label at 0x24233367540>,
#  <InputElement 24233367e50 name='filters[derived_material_type][]' type='checkbox'>,
#  ' ผสม',
#  <Element li at 0x24233367ea0>,
#  <Element a at 0x24233367ef0>,
#  'ทรง',
#  <Element span at 0x24233367f40>,
#  <Element ul at 0x24233367f90>,
#  <InputElement 24233378040 name='filters[frame_shape][]' type='hidden'>,
#  <Element li at 0x24233378090>,
#  <Element label at 0x242333780e0>,
#  <InputElement 24233378130 name='filters[frame_shape][]' type='checkbox'>,
#  ' ทรงเหลี่ยม',
#  <Element li at 0x24233378180>,
#  <Element label at 0x242333781d0>,
#  <InputElement 24233378220 name='filters[frame_shape][]' type='checkbox'>,
#  ' ทรงกลม',
#  <Element li at 0x24233378270>,
#  <Element label at 0x242333782c0>,
#  <InputElement 24233378310 name='filters[frame_shape][]' type='checkbox'>,
#  ' ทรงหยดน้ำ',
#  <Element li at 0x24233378360>,
#  <Element label at 0x242333783b0>,
#  <InputElement 24233378400 name='filters[frame_shape][]' type='checkbox'>,
#  ' ทรงนักบิน',
#  <Element li at 0x24233378450>,
#  <Element label at 0x242333784a0>,
#  <InputElement 242333784f0 name='filters[frame_shape][]' type='checkbox'>,
#  ' ทรงตาแมว',
#  <Element li at 0x24233378540>,
#  <Element a at 0x24233378590>,
#  'ขนาด',
#  <Element span at 0x242333785e0>,
#  <Element ul at 0x24233378630>,
#  <InputElement 24233378680 name='filters[derived_frame_size][]' type='hidden'>,
#  <Element li at 0x242333786d0>,
#  <Element label at 0x24233378720>,
#  <InputElement 24233378770 name='filters[derived_frame_size][]' type='checkbox'>,
#  ' ไซส์ XS',
#  <Element li at 0x242333787c0>,
#  <Element label at 0x24233378810>,
#  <InputElement 24233378860 name='filters[derived_frame_size][]' type='checkbox'>,
#  ' ไซส์ S',
#  <Element li at 0x242333788b0>,
#  <Element label at 0x24233378900>,
#  <InputElement 24233378950 name='filters[derived_frame_size][]' type='checkbox'>,
#  ' ไซส์ M',
#  <Element li at 0x242333789a0>,
#  <Element label at 0x242333789f0>,
#  <InputElement 24233378a40 name='filters[derived_frame_size][]' type='checkbox'>,
#  ' ไซส์ L',
#  <Element li at 0x24233378a90>,
#  <Element a at 0x24233378ae0>,
#  'ราคา',
#  <Element span at 0x24233378b30>,
#  <Element ul at 0x24233378b80>,
#  <InputElement 24233378bd0 name='filters[price][]' type='hidden'>,
#  <Element li at 0x24233378c20>,
#  <Element label at 0x24233378c70>,
#  <InputElement 24233378cc0 name='filters[price][]' type='checkbox'>,
#  ' 1990 หรือถูกกว่า',
#  <Element li at 0x24233378d10>,
#  <Element label at 0x24233378d60>,
#  <InputElement 24233378db0 name='filters[price][]' type='checkbox'>,
#  ' 1991 - 2990',
#  <Element li at 0x24233378e00>,
#  <Element label at 0x24233378e50>,
#  <InputElement 24233378ea0 name='filters[price][]' type='checkbox'>,
#  ' 2991 - 3990',
#  <Element li at 0x24233378ef0>,
#  <Element label at 0x24233378f40>,
#  <InputElement 24233378f90 name='filters[price][]' type='checkbox'>,
#  ' 3991 - 4990',
#  <Element li at 0x2423337c040>,
#  <Element label at 0x2423337c090>,
#  <InputElement 2423337c0e0 name='filters[price][]' type='checkbox'>,
#  ' สูงกว่า 4990',
#  <Element div at 0x2423337c130>,
#  <Element ul at 0x2423337c180>,
#  <Element li at 0x2423337c1d0>,
#  <Element a at 0x2423337c220>,
#  <Element label at 0x2423337c270>,
#  'เรียงตาม:',
#  ' ',
#  <SelectElement 2423337c2c0 name='filters[sort]'>,
#  <Element option at 0x2423337c310>,
#  'ความนิยม',
#  '\n',
#  <Element option at 0x2423337c360>,
#  'ราคาต่ำไปสูง',
#  '\n',
#  <Element option at 0x2423337c3b0>,
#  'ราคาสูงไปต่ำ',
#  <Element li at 0x2423337c400>,
#  <Element a at 0x2423337c450>,
#  <Element label at 0x2423337c4a0>,
#  'มุมภาพ:',
#  ' ',
#  <SelectElement 2423337c4f0 name='filters[view]'>,
#  <Element option at 0x2423337c540>,
#  'ด้านหน้า',
#  '\n',
#  <Element option at 0x2423337c590>,
#  'ด้านข้าง',
#  '\n',
#  <Element option at 0x2423337c5e0>,
#  'ด้านทแยง',
#  '\n',
#  <Element option at 0x2423337c630>,
#  'ลุ๊กบุ๊คผู้หญิง',
#  '\n',
#  <Element option at 0x2423337c680>,
#  'ลุ๊กบุ๊คผู้ชาย',
#  <Element div at 0x2423337c6d0>,
#  <Element form at 0x242332e7d60>,
#  <InputElement 2423337c720 name='utf8' type='hidden'>,
#  <Element div at 0x2423337c770>,
#  <Element div at 0x2423337c7c0>,
#  <Element div at 0x2423337c810>,
#  <Element label at 0x2423337c860>,
#  <InputElement 2423337c8b0 name='filters[hto_only]' type='hidden'>,
#  <InputElement 2423337c900 name='filters[hto_only]' type='checkbox'>,
#  'ลองที่บ้านได้',
#  <Element div at 0x2423337c950>,
#  <Element button at 0x2423337c9a0>,
#  'มุมภาพ & การเรียง',
#  <Element button at 0x2423337c9f0>,
#  'กรองสินค้า',
#  <Element form at 0x242332e7e00>,
#  <InputElement 2423337ca40 name='utf8' type='hidden'>,
#  <Element div at 0x2423337ca90>,
#  <Element div at 0x2423337cae0>,
#  <Element div at 0x2423337cb30>,
#  <Element div at 0x2423337cb80>,
#  <Element h4 at 0x2423337cbd0>,
#  'มุมภาพ & การเรียง',
#  <Element div at 0x2423337cc20>,
#  <Element div at 0x2423337cc70>,
#  <Element div at 0x2423337ccc0>,
#  <Element div at 0x2423337cd10>,
#  <Element h4 at 0x2423337cd60>,
#  'มุมภาพ:',
#  <InputElement 2423337cdb0 name='filters[view]' type='hidden'>,
#  <Element div at 0x2423337ce00>,
#  <Element label at 0x2423337ce50>,
#  <InputElement 2423337cea0 name='filters[view]' type='radio'>,
#  'ด้านหน้า',
#  <Element div at 0x2423337cef0>,
#  <Element label at 0x2423337cf40>,
#  <InputElement 2423337cf90 name='filters[view]' type='radio'>,
#  'ด้านข้าง',
#  <Element div at 0x2423334d040>,
#  <Element label at 0x2423334d090>,
#  <InputElement 2423334d0e0 name='filters[view]' type='radio'>,
#  'ด้านทแยง',
#  <Element div at 0x2423334d130>,
#  <Element label at 0x2423334d180>,
#  <InputElement 2423334d1d0 name='filters[view]' type='radio'>,
#  'ลุ๊กบุ๊คผู้หญิง',
#  <Element div at 0x2423334d220>,
#  <Element label at 0x2423334d270>,
#  <InputElement 2423334d2c0 name='filters[view]' type='radio'>,
#  'ลุ๊กบุ๊คผู้ชาย',
#  <Element div at 0x2423334d310>,
#  <Element div at 0x2423334d360>,
#  <Element div at 0x2423334d3b0>,
#  <Element h4 at 0x2423334d400>,
#  'เรียงตาม:',
#  <InputElement 2423334d450 name='filters[sort]' type='hidden'>,
#  <Element div at 0x2423334d4a0>,
#  <Element label at 0x2423334d4f0>,
#  <InputElement 2423334d540 name='filters[sort]' type='radio'>,
#  'ความนิยม',
#  <Element div at 0x2423334d590>,
#  <Element label at 0x2423334d5e0>,
#  <InputElement 2423334d630 name='filters[sort]' type='radio'>,
#  'ราคาต่ำไปสูง',
#  <Element div at 0x2423334d680>,
#  <Element label at 0x2423334d6d0>,
#  <InputElement 2423334d720 name='filters[sort]' type='radio'>,
#  'ราคาสูงไปต่ำ',
#  <Element div at 0x2423334d770>,
#  <InputElement 2423334d7c0 name='commit' type='submit'>,
#  <Element button at 0x2423334d810>,
#  'ยกเลิก',
#  <Element div at 0x2423334d860>,
#  <Element div at 0x2423334d8b0>,
#  <Element div at 0x2423334d900>,
#  <Element div at 0x2423334d950>,
#  <Element h4 at 0x2423334d9a0>,
#  'กรองสินค้า',
#  <Element div at 0x2423334d9f0>,
#  <Element div at 0x2423334da40>,
#  <Element div at 0x2423334da90>,
#  <Element div at 0x2423334dae0>,
#  <Element h4 at 0x2423334db30>,
#  'สี:',
#  <InputElement 2423334db80 name='filters[color_tone][]' type='hidden'>,
#  <Element div at 0x2423334dbd0>,
#  <Element label at 0x2423334dc20>,
#  <InputElement 2423334dc70 name='filters[color_tone][]' type='checkbox'>,
#  'โทนขาวดำ',
#  <Element div at 0x2423334dcc0>,
#  <Element label at 0x2423334dd10>,
#  <InputElement 2423334dd60 name='filters[color_tone][]' type='checkbox'>,
#  'โทนหลากสี',
#  <Element div at 0x2423334ddb0>,
#  <Element label at 0x2423334de00>,
#  <InputElement 2423334de50 name='filters[color_tone][]' type='checkbox'>,
#  'เอิร์ธโทน',
#  <Element div at 0x2423334dea0>,
#  <Element label at 0x2423334def0>,
#  <InputElement 2423334df40 name='filters[color_tone][]' type='checkbox'>,
#  'โทนสองสี',
#  <Element div at 0x2423334df90>,
#  <Element label at 0x2423337f040>,
#  <InputElement 2423337f090 name='filters[color_tone][]' type='checkbox'>,
#  'โทนสีเดียว',
#  <Element div at 0x2423337f0e0>,
#  <Element div at 0x2423337f130>,
#  <Element div at 0x2423337f180>,
#  <Element h4 at 0x2423337f1d0>,
#  'วัสดุ:',
#  <InputElement 2423337f220 name='filters[derived_material_type][]' type='hidden'>,
#  <Element div at 0x2423337f270>,
#  <Element label at 0x2423337f2c0>,
#  <InputElement 2423337f310 name='filters[derived_material_type][]' type='checkbox'>,
#  'โลหะ',
#  <Element div at 0x2423337f360>,
#  <Element label at 0x2423337f3b0>,
#  <InputElement 2423337f400 name='filters[derived_material_type][]' type='checkbox'>,
#  'พลาสติก',
#  <Element div at 0x2423337f450>,
#  <Element label at 0x2423337f4a0>,
#  <InputElement 2423337f4f0 name='filters[derived_material_type][]' type='checkbox'>,
#  'ผสม',
#  <Element div at 0x2423337f540>,
#  <Element div at 0x2423337f590>,
#  <Element div at 0x2423337f5e0>,
#  <Element h4 at 0x2423337f630>,
#  'รูปทรง:',
#  <InputElement 2423337f680 name='filters[frame_shape][]' type='hidden'>,
#  <Element div at 0x2423337f6d0>,
#  <Element label at 0x2423337f720>,
#  <InputElement 2423337f770 name='filters[frame_shape][]' type='checkbox'>,
#  'ทรงเหลี่ยม',
#  <Element div at 0x2423337f7c0>,
#  <Element label at 0x2423337f810>,
#  <InputElement 2423337f860 name='filters[frame_shape][]' type='checkbox'>,
#  'ทรงกลม',
#  <Element div at 0x2423337f8b0>,
#  <Element label at 0x2423337f900>,
#  <InputElement 2423337f950 name='filters[frame_shape][]' type='checkbox'>,
#  'ทรงหยดน้ำ',
#  <Element div at 0x2423337f9a0>,
#  <Element label at 0x2423337f9f0>,
#  <InputElement 2423337fa40 name='filters[frame_shape][]' type='checkbox'>,
#  'ทรงนักบิน',
#  <Element div at 0x2423337fa90>,
#  <Element label at 0x2423337fae0>,
#  <InputElement 2423337fb30 name='filters[frame_shape][]' type='checkbox'>,
#  'ทรงตาแมว',
#  <Element div at 0x2423337fb80>,
#  <Element div at 0x2423337fbd0>,
#  <Element div at 0x2423337fc20>,
#  <Element h4 at 0x2423337fc70>,
#  'ขนาด:',
#  <InputElement 2423337fcc0 name='filters[derived_frame_size][]' type='hidden'>,
#  <Element div at 0x2423337fd10>,
#  <Element label at 0x2423337fd60>,
#  <InputElement 2423337fdb0 name='filters[derived_frame_size][]' type='checkbox'>,
#  'ไซส์ XS',
#  <Element div at 0x2423337fe00>,
#  <Element label at 0x2423337fe50>,
#  <InputElement 2423337fea0 name='filters[derived_frame_size][]' type='checkbox'>,
#  'ไซส์ S',
#  <Element div at 0x2423337fef0>,
#  <Element label at 0x2423337ff40>,
#  <InputElement 2423337ff90 name='filters[derived_frame_size][]' type='checkbox'>,
#  'ไซส์ M',
#  <Element div at 0x24233356040>,
#  <Element label at 0x24233356090>,
#  <InputElement 242333560e0 name='filters[derived_frame_size][]' type='checkbox'>,
#  'ไซส์ L',
#  <Element div at 0x24233356130>,
#  <Element div at 0x24233356180>,
#  <Element div at 0x242333561d0>,
#  <Element h4 at 0x24233356220>,
#  'ราคา:',
#  <InputElement 24233356270 name='filters[price][]' type='hidden'>,
#  <Element div at 0x242333562c0>,
#  <Element label at 0x24233356310>,
#  <InputElement 24233356360 name='filters[price][]' type='checkbox'>,
#  '1990 หรือถูกกว่า',
#  <Element div at 0x242333563b0>,
#  <Element label at 0x24233356400>,
#  <InputElement 24233356450 name='filters[price][]' type='checkbox'>,
#  '1991 - 2990',
#  <Element div at 0x242333564a0>,
#  <Element label at 0x242333564f0>,
#  <InputElement 24233356540 name='filters[price][]' type='checkbox'>,
#  '2991 - 3990',
#  <Element div at 0x24233356590>,
#  <Element label at 0x242333565e0>,
#  <InputElement 24233356630 name='filters[price][]' type='checkbox'>,
#  '3991 - 4990',
#  <Element div at 0x24233356680>,
#  <Element label at 0x242333566d0>,
#  <InputElement 24233356720 name='filters[price][]' type='checkbox'>,
#  'สูงกว่า 4990',
#  <Element div at 0x24233356770>,
#  <InputElement 242333567c0 name='commit' type='submit'>,
#  <Element button at 0x24233356810>,
#  'ยกเลิก',
#  <Element div at 0x24233356860>,
#  <Element div at 0x242333568b0>,
#  <Element div at 0x24233356900>,
#  <Element div at 0x24233356950>,
#  <Element div at 0x242333569a0>,
#  <Element div at 0x242333569f0>,
#  <Element div at 0x24233356a40>,
#  <Element a at 0x24233356a90>,
#  <Element div at 0x24233356ae0>,
#  <Element div at 0x24233356b30>,
#  'Edwin',
#  <Element div at 0x24233356b80>,
#  <Element span at 0x24233356bd0>,
#  '3,990 ฿',
#  <Element div at 0x24233356c20>,
#  <Element div at 0x24233356c70>,
#  <Element div at 0x24233356cc0>,
#  <Element div at 0x24233356d10>,
#  <Element div at 0x24233356d60>,
#  <Element a at 0x24233356db0>,
#  <Element div at 0x24233356e00>,
#  <Element div at 0x24233356e50>,
#  'Theo',
#  <Element div at 0x24233356ea0>,
#  <Element span at 0x24233356ef0>,
#  '3,990 ฿',
#  <Element div at 0x24233356f40>,
#  <Element div at 0x24233356f90>,
#  <Element div at 0x24233344040>,
#  <Element div at 0x24233344090>,
#  <Element div at 0x242333440e0>,
#  <Element a at 0x24233344130>,
#  <Element div at 0x24233344180>,
#  <Element div at 0x242377897c0>,
#  'Wilson',
#  <Element div at 0x242333441d0>,
#  <Element span at 0x24233344220>,
#  '2,990 ฿',
#  <Element div at 0x24233344270>,
#  <Element div at 0x242333442c0>,
#  <Element div at 0x24233344310>,
#  <Element div at 0x24233344360>,
#  <Element div at 0x242333443b0>,
#  <Element a at 0x24233344400>,
#  <Element div at 0x24233344450>,
#  <Element div at 0x242333444a0>,
#  'Lowel',
#  <Element div at 0x242333444f0>,
#  <Element span at 0x24233344540>,
#  '3,990 ฿',
#  <Element div at 0x24233344590>,
#  <Element div at 0x242333445e0>,
#  <Element div at 0x24233344630>,
#  <Element div at 0x24233344680>,
#  <Element div at 0x242333446d0>,
#  <Element a at 0x24233344720>,
#  <Element div at 0x24233344770>,
#  <Element div at 0x242333447c0>,
#  'Nobel',
#  <Element div at 0x24233344810>,
#  <Element span at 0x24233344860>,
#  '3,990 ฿',
#  <Element div at 0x242333448b0>,
#  <Element div at 0x24233344900>,
#  <Element div at 0x24233344950>,
#  <Element div at 0x242333449a0>,
#  <Element div at 0x242333449f0>,
#  <Element a at 0x24233344a40>,
#  <Element div at 0x24233344a90>,
#  <Element div at 0x24233344ae0>,
#  'Hugo',
#  <Element div at 0x24233344b30>,
#  <Element span at 0x24233344b80>,
#  '3,990 ฿',
#  <Element div at 0x24233344bd0>,
#  <Element div at 0x24233344c20>,
#  <Element div at 0x24233344c70>,
#  <Element div at 0x24233344cc0>,
#  <Element div at 0x24233344d10>,
#  <Element a at 0x24233344d60>,
#  <Element div at 0x24233344db0>,
#  <Element div at 0x24233344e00>,
#  'Elton',
#  <Element div at 0x24233344e50>,
#  <Element span at 0x24233344ea0>,
#  '3,990 ฿',
#  <Element div at 0x24233344ef0>,
#  <Element div at 0x24233344f40>,
#  <Element div at 0x24233344f90>,
#  <Element div at 0x24233370040>,
#  <Element div at 0x24233370090>,
#  <Element a at 0x242333700e0>,
#  <Element div at 0x24233370130>,
#  <Element div at 0x24233370180>,
#  'Luther',
#  <Element div at 0x242333701d0>,
#  <Element span at 0x24233370220>,
#  '2,990 ฿',
#  <Element br at 0x24233370270>,
#  <Element div at 0x242333702c0>,
#  <Element div at 0x24233370310>,
#  <Element ul at 0x24233370360>,
#  <Element li at 0x242333703b0>,
#  <Element a at 0x24233370400>,
#  '<',
#  <Element li at 0x24233370450>,
#  <Element a at 0x242333704a0>,
#  '1',
#  <Element li at 0x242333704f0>,
#  <Element a at 0x24233370540>,
#  '2',
#  <Element li at 0x24233370590>,
#  <Element a at 0x242333705e0>,
#  '3',
#  <Element li at 0x24233370630>,
#  <Element a at 0x24233370680>,
#  '4',
#  <Element li at 0x242333706d0>,
#  <Element a at 0x24233370720>,
#  '5',
#  <Element li at 0x24233370770>,
#  <Element a at 0x242333707c0>,
#  '>',
#  <Element div at 0x24233370810>,
#  '(',
#  <Element span at 0x24233370860>,
#  'Display Entries',
#  ')',
#  <Element section at 0x242333708b0>,
#  <Element div at 0x24233370900>,
#  <Element div at 0x24233370950>,
#  '\n              ',
#  <Element div at 0x242333709a0>,
#  '\n                ',
#  <Element h1 at 0x242333709f0>,
#  'แว่นสายตา กรอบ+เลนส์ย่อบาง(1.6) เริ่ม 1,990 บาท',
#  '\n                ',
#  <Element p at 0x24233370a40>,
#  'กรอบแว่นของเราถูกออกแบบและผลิตมาอย่างพิถีพิถันตั้งแต่รูปทรง สีสัน และวัสดุ โดยคำนึงถึงความลงตัวของสไตล์และการใช้งานได้จริงเป็นสำคัญ ในส่วนของเลนส์ เราเลือกใช้เลนส์คุณภาพสูงสั่งผลิตโดยตรงจากโรงงานที่มีความเชี่ยวชาญและเชื่อถือได้ เพราะเราเชื่อว่าแว่นตาที่ดีนอกจากสวยงามทนทานแล้ว ยังต้องถนอมสายตาของผู้ใช้งานได้อย่างดีที่สุด กรอบและเลนส์ของเราจะถูกประกอบขึ้นจากโรงงาน และจัดส่งถึงมือคุณที่บ้านโดยตรง ทำให้เราสามารถมอบสินค้าที่ดีมีคุณภาพในราคาที่เหมาะสมและคุ้มค่า',
#  '\n              ',
#  '\n              ',
#  <Element div at 0x24233370a90>,
#  '\n                ',
#  <Element h2 at 0x24233370ae0>,
#  'เลนส์สายตาย่อบาง 1.6',
#  '\n                ',
#  <Element p at 0x24233370b30>,
#  'ในขณะที่ร้านแว่นเจ้าอื่นใช้เลนส์มาตรฐานที่ไม่เกิน 1.56 เลนส์มาตรฐานของเราจะเริ่มต้นที่ 1.6 ที่จะมีความบางและเบากว่าเลนส์มาตรฐานที่ใช้ตามท้องตลาด สามารถรองรับค่าสายตาสั้นถึงยาวที่ -4.75 ถึง +4.75 ได้สบายๆ',
#  '\n              ',
#  '\n              ',
#  <Element div at 0x24233370b80>,
#  '\n                ',
#  <Element h2 at 0x24233370bd0>,
#  'เลนส์สายตาย่อบางพิเศษ 1.67',
#  '\n                ',
#  <Element p at 0x24233370c20>,
#  'ทางเลือกพิเศษสำหรับผู้ที่มีค่าสายตายาวมากกว่า +4.75 หรือค่าสายตาสั้นมากกว่า -4.75 เลนส์ย่อบางพิเศษขนาด 1.67 ที่มีความเบาบางลงจากเลนส์ย่อบาง 1.6 ถึง 30% สามารถรองรับค่าสายตาได้ถึง +/- 10.00  ช่วยให้สามารถเลือกจับคุ่กับกรอบแว่นที่ชอบได้อย่างเป็นอิสระมากขึ้น โดยไม่ต้องกังวลเรื่องความหนา น้ำหนัก และยังใช้งานได้อย่างสบายตามากขึ้นอีกด้วย',
#  '\n              ',
#  '\n              ',
#  <Element div at 0x24233370c70>,
#  '\n                ',
#  <Element h2 at 0x24233370cc0>,
#  'เลนส์กรองแสงสีฟ้า',
#  '\n                ',
#  <Element p at 0x24233370d10>,
#  'สำหรับคนรุ่นใหม่ที่ต้องใช้ชีวิตอยู่หน้าจอคอมและมือถือ แสงสีฟ้าจากหน้าจอสามารถทำอันตรายกับดวงตาเราได้ไม่แพ้รังสี UV เรามีเลนส์ที่ป้องกันแสงสีฟ้าจากหน้าจอให้เป็นตัวเลือก เพื่อปกป้องรักษาดวงตาที่มีอยู่เพียงคู่เดียวของคุณ',
#  '\n                ',
#  <Element p at 0x24233370d60>,
#  'บริการลองแว่นที่บ้านได้ | รับประกัน 1 ปี | สั่งซื้อแว่นตาออนไลน์ได้',
#  '\n              ',
#  '\n            ',
#  <Element footer at 0x24233370db0>,
#  <Element div at 0x24233370e00>,
#  <Element div at 0x24233370e50>,
#  <Element div at 0x24233370ea0>,
#  <Element div at 0x24233370ef0>,
#  <Element div at 0x24233370f40>,
#  <Element div at 0x24233370f90>,
#  <Element div at 0x24237ebb040>,
#  'Product Categories',
#  <Element div at 0x24237ebb090>,
#  <Element div at 0x242333677c0>,
#  <Element a at 0x2423335e1d0>,
#  'แว่นสายตา',
#  <Element div at 0x2423335e0e0>,
#  <Element a at 0x24237ebb0e0>,
#  'แว่นกันแดด',
#  <Element div at 0x24237ebb130>,
#  <Element a at 0x24237ebb180>,
#  'แว่นเลนส์สี',
#  <Element div at 0x24237ebb1d0>,
#  <Element a at 0x24237ebb220>,
#  'แว่นเลนส์ฟิลเตอร์',
#  <Element div at 0x24237ebb270>,
#  <Element div at 0x24237ebb2c0>,
#  <Element div at 0x24237ebb310>,
#  'ความเป็นมาของเรา',
#  <Element div at 0x24237ebb360>,
#  <Element div at 0x24237ebb3b0>,
#  <Element a at 0x24237ebb400>,
#  'เกี่ยวกับเรา',
#  <Element div at 0x24237ebb450>,
#  <Element a at 0x24237ebb4a0>,
#  'การออกแบบ',
#  <Element div at 0x24237ebb4f0>,
#  <Element a at 0x24237ebb540>,
#  'ประสบการณ์การซื้อ',
#  <Element div at 0x24237ebb590>,
#  <Element a at 0x24237ebb5e0>,
#  'บทความ',
#  <Element div at 0x24237ebb630>,
#  <Element div at 0x24237ebb680>,
#  'งาน',
#  <Element div at 0x24237ebb6d0>,
#  <Element div at 0x24237ebb720>,
#  <Element a at 0x24237ebb770>,
#  'โอกาส',
#  <Element div at 0x24237ebb7c0>,
#  <Element a at 0x24237ebb810>,
#  'ทีม',
#  <Element div at 0x24237ebb860>,
#  <Element div at 0x24237ebb8b0>,
#  <Element div at 0x24237ebb900>,
#  'ความช่วยเหลือ',
#  <Element div at 0x24237ebb950>,
#  <Element div at 0x24237ebb9a0>,
#  <Element a at 0x24237ebb9f0>,
#  'คำถามที่พบบ่อย',
#  <Element div at 0x24237ebba40>,
#  <Element a at 0x24237ebba90>,
#  'การสั่งซื้อสินค้า',
#  <Element div at 0x24237ebbae0>,
#  <Element a at 0x24237ebbb30>,
#  'เลือกแว่นไปลองที่บ้าน',
#  <Element div at 0x24237ebbb80>,
#  <Element div at 0x24237ebbbd0>,
#  'ติดต่อเรา',
#  <Element div at 0x24237ebbc20>,
#  <Element div at 0x24237ebbc70>,
#  <Element a at 0x24237ebbcc0>,
#  'โชว์รูม',
#  <Element div at 0x24237ebbd10>,
#  <Element a at 0x24237ebbd60>,
#  'บริการวัดสายตา',
#  <Element div at 0x24237ebbdb0>,
#  <Element a at 0x24237ebbe00>,
#  'ช่องทางออนไลน์',
#  <Element div at 0x24237ebbe50>,
#  <Element a at 0x24237ebbea0>,
#  'นโยบายความเป็นส่วนตัว',
#  <Element div at 0x24237ebbef0>,
#  <Element div at 0x24237ebbf40>,
#  <Element div at 0x24237ebbf90>,
#  <Element div at 0x24237ed1040>,
#  <Element div at 0x24237ed1090>,
#  <Element div at 0x24237ed10e0>,
#  'พาร์ทเนอร์ด้านธุรกิจออพติคอล',
#  <Element div at 0x24237ed1130>,
#  <Element div at 0x24237ed1180>,
#  <Element img at 0x24237ed11d0>,
#  <Element div at 0x24237ed1220>,
#  <Element img at 0x24237ed1270>,
#  <Element div at 0x24237ed12c0>,
#  <Element img at 0x24237ed1310>,
#  <Element div at 0x24237ed1360>,
#  <Element img at 0x24237ed13b0>,
#  <Element div at 0x24237ed1400>,
#  <Element div at 0x24237ed1450>,
#  <Element div at 0x24237ed14a0>,
#  <Element div at 0x24237ed14f0>,
#  'ช่องทางการติดต่อ',
#  <Element div at 0x24237ed1540>,
#  <Element div at 0x24237ed1590>,
#  <Element i at 0x24237ed15e0>,
#  <Element div at 0x24237ed1630>,
#  <Element a at 0x24237ed1680>,
#  '080-549-8265',
#  <Element div at 0x24237ed16d0>,
#  <Element h5 at 0x24237ed1720>,
#  'LINE',
#  <Element div at 0x24237ed1770>,
#  <Element a at 0x24237ed17c0>,
#  '@glazziq',
#  <Element div at 0x24237ed1810>,
#  <Element i at 0x24237ed1860>,
#  <Element div at 0x24237ed18b0>,
#  <Element a at 0x24237ed1900>,
#  'help@glazziq.com',
#  <Element script at 0x24237ed1950>,
#  '\n    (function () {\n        var options = {\n            facebook: "1499454373629055", // Facebook page ID\n            line: "//line.me/R/ti/p/%40got9016w", // Line QR code URL\n            call_to_action: "Chat With Us", // Call to action\n            button_color: "#666666", // Color of button\n            position: "right", // Position may be \'right\' or \'left\'\n            order: "facebook,line", // Order of buttons\n        };\n        var proto = document.location.protocol, host = "getbutton.io", url = proto + "//static." + host;\n        var s = document.createElement(\'script\'); s.type = \'text/javascript\'; s.async = true; s.src = url + \'/widget-send-button/js/init.js\';\n        s.onload = function () { WhWidgetSendButton.init(host, proto, options); };\n        var x = document.getElementsByTagName(\'script\')[0]; x.parentNode.insertBefore(s, x);\n    })();\n',
#  '\n']

# %%
from selenium import webdriver
from selenium.webdriver.remote.webelement import WebElement
driver = webdriver.PhantomJS()
driver.get(url)
