# %% [markdown]
# ## a. Why should the data be partitioned into training and validation sets? What will the training set be used for? What will the validation set be used for?

# %% [markdown]
# The data should be partitioned so that after the training, the model will have something that it hasn't seen before to predict on. As such, the training set is used to for learning and to fit the parameters, while the validation set is used to tune the hyperparameters.

# %% [markdown]
# ## b. Fit a multiple linear regression model to the median house price (MEDV) as a function of CRIM, CHAS, and RM. Write the equation for predicting the median house price from the predictors in the model.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
housing = pd.read_csv('3/BostonHousing.csv')

# %%
X = housing[['CRIM','CHAS','RM']]
y = housing['MEDV']

# %%
train_X, valid_X, train_y, valid_y = train_test_split(X,y, test_size=.3, random_state=10)

# %%
regr = LinearRegression()
regr.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
regr.intercept_
# Out:
# -27.87615474886597

# %%
regr.coef_
# Out:
# array([-0.29594781,  2.22379595,  8.11607882])

# %% [markdown]
# **Equation: MEDV = -27.876 + (-0.296 CRIM) + 2.224 CHAS + 8.116 RM**

# %% [markdown]
# ## c. Using the estimated regression model, what median house price is predicted for a tract in the Boston area that does not bound the Charles River, has a crime rate of 0.1, and where the average number of rooms per house is 6?

# %%
regr.predict(np.array([[0.1,0,6]]))
# Out:
# array([20.79072341])

# %% [markdown]
# **MEDV = -27.876 -0.296 * 0.1 + 2.224 * 0 + 8.116 * 6 = 20.79 thousand**

# %% [markdown]
# ## d. Reduce the number of predictors:
# ### i. Which predictors are likely to be measuring the same thing among the 13 predictors? Discuss the relationships among INDUS, NOX, and TAX.

# %% [markdown]
# Thinking logically, there's likely a positive relationship between INDUS, NOX and TAX because Boston being a well developed city, the higher the proportion of non-retail business (e.g. industrial businesses), the higher the polution as well as taxes in the region.

# %% [markdown]
# ### ii. Compute the correlation table for the 12 numerical predictors and search for highly correlated pairs. These have potential redundancy and can cause multicollinearity. Choose which ones to remove based on this table.

# %%
housing.dtypes
# Out:
# CRIM         float64
# ZN           float64
# INDUS        float64
# CHAS           int64
# NOX          float64
# RM           float64
# AGE          float64
# DIS          float64
# RAD            int64
# TAX            int64
# PTRATIO      float64
# LSTAT        float64
# MEDV         float64
# CAT. MEDV      int64
# dtype: object

# %%
corr = housing.iloc[: , :12].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0d81e_row0_col0,#T_0d81e_row1_col1,#T_0d81e_row2_col2,#T_0d81e_row3_col3,#T_0d81e_row4_col4,#T_0d81e_row5_col5,#T_0d81e_row6_col6,#T_0d81e_row7_col7,#T_0d81e_row8_col8,#T_0d81e_row9_col9,#T_0d81e_row10_col10,#T_0d81e_row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0d81e_row0_col1,#T_0d81e_row3_col0{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_0d81e_row0_col2{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_0d81e_row0_col3{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_0d81e_row0_col4{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_0d81e_row0_col5{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_0d81e_row0_col6{
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }#T_0d81e_row0_col7{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_0d81e_row0_col8,#T_0d81e_row4_col11{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_0d81e_row0_col9,#T_0d81e_row2_col8,#T_0d81e_row8_col0{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_0d81e_row0_col10{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_0d81e_row0_col11{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_0d81e_row1_col0,#T_0d81e_row9_col7{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_0d81e_row1_col2,#T_0d81e_row1_col6,#T_0d81e_row8_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_0d81e_row1_col3{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_0d81e_row1_col4,#T_0d81e_row1_col9{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_0d81e_row1_col5{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_0d81e_row1_col7,#T_0d81e_row9_col4{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_0d81e_row1_col8,#T_0d81e_row1_col11{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_0d81e_row1_col10,#T_0d81e_row4_col7,#T_0d81e_row5_col11,#T_0d81e_row6_col1,#T_0d81e_row7_col0,#T_0d81e_row7_col2,#T_0d81e_row7_col4,#T_0d81e_row7_col6,#T_0d81e_row7_col8,#T_0d81e_row7_col9,#T_0d81e_row10_col3,#T_0d81e_row11_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_0d81e_row2_col0{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_0d81e_row2_col1,#T_0d81e_row7_col3{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_0d81e_row2_col3,#T_0d81e_row8_col1{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_0d81e_row2_col4{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_0d81e_row2_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_0d81e_row2_col6{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_0d81e_row2_col7,#T_0d81e_row4_col1{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_0d81e_row2_col9{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_0d81e_row2_col10{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_0d81e_row2_col11{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_0d81e_row3_col1{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_0d81e_row3_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_0d81e_row3_col4,#T_0d81e_row10_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_0d81e_row3_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_0d81e_row3_col6{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_0d81e_row3_col7{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_0d81e_row3_col8,#T_0d81e_row3_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_0d81e_row3_col10,#T_0d81e_row4_col5{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_0d81e_row3_col11{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_0d81e_row4_col0{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_0d81e_row4_col2{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_0d81e_row4_col3,#T_0d81e_row5_col3,#T_0d81e_row5_col8{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_0d81e_row4_col6{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_0d81e_row4_col8{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_0d81e_row4_col9{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_0d81e_row4_col10{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_0d81e_row5_col0,#T_0d81e_row7_col10,#T_0d81e_row10_col1{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_0d81e_row5_col1{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_0d81e_row5_col2,#T_0d81e_row6_col3{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_0d81e_row5_col4{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_0d81e_row5_col6{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_0d81e_row5_col7{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_0d81e_row5_col9,#T_0d81e_row10_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_0d81e_row5_col10{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_0d81e_row6_col0{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_0d81e_row6_col2{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_0d81e_row6_col4{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_0d81e_row6_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_0d81e_row6_col7{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_0d81e_row6_col8{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_0d81e_row6_col9{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_0d81e_row6_col10{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_0d81e_row6_col11{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_0d81e_row7_col1{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_0d81e_row7_col5{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_0d81e_row7_col11{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_0d81e_row8_col2{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_0d81e_row8_col4{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_0d81e_row8_col5{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_0d81e_row8_col6{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_0d81e_row8_col7,#T_0d81e_row11_col7{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_0d81e_row8_col9{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_0d81e_row8_col10{
#             back

# %% [markdown]
# From above, we see that the following variable pairs are highly correlated:
#  NOX and INDUS: Correlation coefficient = 0.76365
#
#  TAX and INDUS: Correlation coefficient = 0.72076
#
#  AGE and NOX: Correlation coefficient = 0.73147
#
#  DIS and NOX: Correlation coefficient = -0.76923
#
#  DIS and INDUS: Correlation coefficient = -0.70803
#
#  DIS and AGE: Correlation coefficient = -0.74788
#
#  TAX and RAD: Correlation coefficient = 0.91023
#
# **Variables to be removed: TAX, INDUS, NOX, AGE**

# %% [markdown]
# Correlation Matrix after removing the four variables

# %%
corr = housing[['CRIM', 'ZN', 'CHAS', 'RM', 'DIS', 'RAD', 'PTRATIO', 'LSTAT']].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_4c5d0_row0_col0,#T_4c5d0_row1_col1,#T_4c5d0_row2_col2,#T_4c5d0_row3_col3,#T_4c5d0_row4_col4,#T_4c5d0_row5_col5,#T_4c5d0_row6_col6,#T_4c5d0_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4c5d0_row0_col1{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_4c5d0_row0_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_4c5d0_row0_col3{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_4c5d0_row0_col4{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_4c5d0_row0_col5{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_4c5d0_row0_col6{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_4c5d0_row0_col7{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_4c5d0_row1_col0{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_4c5d0_row1_col2{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_4c5d0_row1_col3{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_4c5d0_row1_col4{
#             background-color:  #f18f71;
#             color:  #000000;
#         }#T_4c5d0_row1_col5,#T_4c5d0_row1_col7{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_4c5d0_row1_col6,#T_4c5d0_row3_col7,#T_4c5d0_row4_col0,#T_4c5d0_row4_col5,#T_4c5d0_row5_col4,#T_4c5d0_row6_col2,#T_4c5d0_row7_col1,#T_4c5d0_row7_col3,#T_4c5d0_row7_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_4c5d0_row2_col0{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_4c5d0_row2_col1{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_4c5d0_row2_col3{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_4c5d0_row2_col4{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_4c5d0_row2_col5{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_4c5d0_row2_col6{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_4c5d0_row2_col7{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_4c5d0_row3_col0,#T_4c5d0_row4_col6{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_4c5d0_row3_col1{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_4c5d0_row3_col2,#T_4c5d0_row3_col5{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_4c5d0_row3_col4{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_4c5d0_row3_col6{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_4c5d0_row4_col1{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_4c5d0_row4_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_4c5d0_row4_col3{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_4c5d0_row4_col7,#T_4c5d0_row5_col1{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_4c5d0_row5_col0{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_4c5d0_row5_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_4c5d0_row5_col3{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_4c5d0_row5_col6{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_4c5d0_row5_col7{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_4c5d0_row6_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_4c5d0_row6_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_4c5d0_row6_col3{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_4c5d0_row6_col4{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_4c5d0_row6_col5{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_4c5d0_row6_col7{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_4c5d0_row7_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_4c5d0_row7_col2{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_4c5d0_row7_col5{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_4c5d0_row7_col6{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }</style><table id="T_4c5d0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CRIM</th>        <th class="col_heading level0 col1" >ZN</th>        <th class="col_heading level0 col2" >CHAS</th>        <th class="col_heading level0 col3" >RM</th>        <th class="col_heading level0 col4" >DIS</th>        <th class="col_heading level0 col5" >RAD</th>        <th class="col_heading level0 col6" >PTRATIO</th>        <th class="col_heading level0 col7" >LSTAT</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c5d0_level0_row0" class="row_heading level0 row0" >CRIM</th>
#                         <td id="T_4c5d0_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4c5d0_row0_col1" class="data row0 col1" >-0.200469</td>
#                         <td id="T_4c5d0_row0_col2" class="data row0 col2" >-0.055892</td>
#                         <td id="T_4c5d0_row0_col3" class="data row0 col3" >-0.219247</td>
#                         <td id="T_4c5d0_row0_col4" class="data row0 col4" >-0.379670</td>
#                         <td id="T_4c5d0_row0_col5" class="data row0 col5" >0.625505</td>
#                         <td id="T_4c5d0_row0_col6" class="data row0 col6" >0.289946</td>
#                         <td id="T_4c5d0_row0_col7" class="data row0 col7" >0.455621</td>
#             </tr>
#             <tr>
#                         <th id="T_4c5d0_level0_row1" class="row_heading level0 row1" >ZN</th>
#                         <td id="T_4c5d0_row1_col0" class="data row1 col0" >-0.200469</td>
#                         <td id="T_4c5d0_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_4c5d0_row1_col2" class="data row1 col2" >-0.042697</td>
#                         <td id="T_4c5d0_row1_col3" class="data row1 col3" >0.311991</td>
#                         <td id="T_4c5d0_row1_col4" class="data row1 col4" >0.664408</td>
#                         <td id="T_4c5d0_row1_col5" class="data row1 col5" >-0.311948</td>
#                         <td id="T_4c5d0_row1_col6" class="data row1 col6" >-0.391679</td>
#                         <td id="T_4c5d0_row1_col7" class="data row1 col7" >-0.412995</td>
#             </tr>
#             <tr>
#                         <th id="T_4c5d0_level0_row2" class="row_heading level0 row2" >CHAS</th>
#                         <td id="T_4c5d0_row2_col0" class="data row2 col0" >-0.055892</td>
#                         <td id="T_4c5d0_row2_col1" class="data row2 col1" >-0.042697</td>
#                         <td id="T_4c5d0_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_4c5d0_row2_col3" class="data row2 col3" >0.091251</td>
#                         <td id="T_4c5d0_row2_col4" class="data row2 col4" >-0.099176</td>
#                         <td id="T_4c5d0_row2_col5" class="data row2 col5" >-0.007368</td>
#                         <td id="T_4c5d0_row2_col6" class="data row2 col6" >-0.121515</td>
#                         <td id="T_4c5d0_row2_col7" class="data row2 col7" >-0.053929</td>
#             </tr>
#             <tr>
#                         <th id="T_4c5d0_level0_row3" class="row_heading level0 row3" >RM</th>
